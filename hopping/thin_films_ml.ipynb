# %%
import pandas as pd
import numpy as np
import sklearn
from matplotlib import pyplot as plt

from src.lib import ThinFilmDatabase

# %%
df = ThinFilmDatabase.load_df()

print('Available columns:', ', '.join(df.columns.to_numpy()))
x = np.log10(df['TL10_15':'TL10_25']['stoichiometry_x'].to_numpy())
y = df['TL10_15':'TL10_25']['crystallite_size'].to_numpy()

plt.scatter(x, y)
plt.xlabel('Deviation from stoichiometry')
plt.ylabel('Crystallite size [nm]')
plt.xticks(x)
plt.show()
# Out:
# Available columns: thickness_nm, oxygen_pressure, stoichiometry_x, rutile_fraction, epsilon_serial, epsilon_parallel, effective_mass, crystallite_size
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 11
#       9 plt.ylabel('Crystallite size [nm]')
#      10 plt.xticks(x)
# ---> 11 plt.xtick_labels()
#      12 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xtick_labels'
