# %% [markdown]
# # Sandbox for exploratory data analysis (EDA)

# %%
import os
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
'''
Datasets for sandbox were downloaded from kaggle using:
curl -L -o ~/Downloads/netflix-movies-and-tv-shows-till-2025.zip\
  https://www.kaggle.com/api/v1/datasets/download/bhargavchirumamilla/netflix-movies-and-tv-shows-till-2025
'''

movies_df = pd.read_csv('netflix_movies_detailed_up_to_2025.csv')
print('Available columns:')
print(' | '.join(movies_df.columns))

print()
print('Top 10 directors with most films at Netflix:')
print(movies_df['director'].value_counts().head(10).to_string())
# Out:
# Available columns:
# show_id | type | title | director | cast | country | date_added | release_year | rating | duration | genres | language | description | popularity | vote_count | vote_average | budget | revenue
#
# Top 10 directors with most films at Netflix:
# director
# Tyler Perry          20
# Roel Reiné           15
# Steven Soderbergh    15
# Sean McNamara        15
# Choi Woo-seong       14
# Sam Liu              13
# Ernie Barbarash      13
# Jesse V. Johnson     13
# Peter Sullivan       13
# Don Michael Paul     13
